# %%
import pandas as pd
import spacy
import spacy_entity_linker

# python -m spacy download en_core_web_lg
nlp = spacy.load("en_core_web_sm")

# Load dataset
df = pd.read_csv("emission_rule_news_steven.csv")

# Function to filter out fully capitalized lines
def filter_capitalized_paragraphs(text):
    # Split the text into lines for processing
    lines = text.split("\n")
    # Filter out lines that are fully capitalized and have more than 2 words
    filtered_lines = [
        line for line in lines
        if not (line.isupper() and len(line.split()) > 2)
    ]
    # Rejoin filtered lines into a single string
    return " ".join(filtered_lines)

df['filtered_maintext'] = df['maintext'].astype(str).apply(filter_capitalized_paragraphs)

# Initialize a dictionary to store entities
extracted_entities = []

for index, row in df.iterrows():
    article_id = row['id']  # Get the Article ID
    article_text = row['filtered_maintext']  # Get the filtered text
    publish_date = row['date_publish']
    url = row['news_url']

    # Process the article
    doc = nlp(article_text)

    # collecting the entities in array
    entities = []
    # classifier
    classifier = spacy_entity_linker.EntityClassifier.EntityClassifier()
    for ent in doc.ents:
        if ent.label_ in {"ORG"}:
            # build a term candidate (a simple span)
            termCandidate = spacy_entity_linker.TermCandidate.TermCandidate(ent)
            # get all the candidates for the term
            entityCandidates = termCandidate.get_entity_candidates()
            if len(entityCandidates) > 0:
                # select the best candidate
                entity = classifier(entityCandidates)
                # entity.span.sent._.linkedEntities.append(entity) # --> cannot if the attribute is not registered
                entities.append(entity)
            else:
                entity = None
            # print(f'SpaCy: {(ent.text + " " + ent.label_).ljust(40)}spaCy-entity-linker: {entity}')

            extracted_entities.append({
                "Article ID": article_id,  # Add the Article ID
                "Label": ent.label_,
                "Pattern": ent.text,
                "Entity": entity,
                "Publish Date": publish_date,
                "Article URL": url
            })
            
output_df = pd.DataFrame(extracted_entities)

# Save the DataFrame to a CSV file
output_file_path = "emission_extracted_entities_org_linker.csv"
output_df.to_csv(output_file_path, index=False)

# %%
output_df
# Out:
#        Article ID Label                            Pattern  \
# 0              32   ORG                U.S. Postal Service
# 1              32   ORG                               USPS
# 2              32   ORG                               SEIS
# 3              32   ORG  Next Generation Delivery Vehicles
# 4              32   ORG                               SEIS
# ...           ...   ...                                ...
# 59804       91445   ORG                    the White House
# 59805       91445   ORG                             Senate
# 59806       91445   ORG                     Administration
# 59807       91445   ORG                                EPA
# 59808       91445   ORG                    the White House
#
#                                               Entity         Publish Date  \
# 0                                               None  2023-07-26 10:42:02
# 1                                               None  2023-07-26 10:42:02
# 2          Seismic Experiment for Interior Structure  2023-07-26 10:42:02
# 3                                               None  2023-07-26 10:42:02
# 4          Seismic Experiment for Interior Structure  2023-07-26 10:42:02
# ...                                              ...                  ...
# 59804                                    White House  2023-09-15 12:50:33
# 59805                           United States Senate  2023-09-15 12:50:33
# 59806                                   receivership  2023-09-15 12:50:33
# 59807  United States Environmental Protection Agency  2023-09-15 12:50:33
# 59808                                    White House  2023-09-15 12:50:33
#
#                                              Article URL
# 0      https://www.commondreams.org/opinion/usps-elec...
# 1      https://www.commondreams.org/opinion/usps-elec...
# 2      https://www.commondreams.org/opinion/usps-elec...
# 3      https://www.commondreams.org/opinion/usps-elec...
# 4      https://www.commondreams.org/opinion/usps-elec...
# ...                                                  ...
# 59804  https://www.oann.com/newsroom/house-passes-bil...
# 59805  https://www.oann.com/newsroom/house-passes-bil...
# 59806  https://www.oann.com/newsroom/house-passes-bil...
# 59807  https://www.oann.com/newsroom/house-passes-bil...
# 59808  https://www.oann.com/newsroom/house-passes-bil...
#
# [59809 rows x 6 columns]

# %%
df
# Out:
#          id                                           news_url  \
# 0        32  https://www.commondreams.org/opinion/usps-elec...
# 1        42  https://www.wmur.com/article/the-epas-ambitiou...
# 2        77  https://whyy.org/articles/delaware-electric-ve...
# 3        78  https://whyy.org/articles/delaware-legislature...
# 4        96  https://www.nbcdfw.com/news/national-internati...
# ...     ...                                                ...
# 2921  91221  https://www.clickondetroit.com/business/2023/0...
# 2922  91237  https://www.clickondetroit.com/business/2023/1...
# 2923  91346  https://www.zerohedge.com/technology/visualizi...
# 2924  91349  https://www.zerohedge.com/political/biden-admi...
# 2925  91445  https://www.oann.com/newsroom/house-passes-bil...
#
#              date_publish                           authors  \
# 0     2023-07-26 10:42:02    annie-norman, www.facebook.com
# 1     2023-08-06 17:09:00                       Tom Krisher
# 2     2023-08-03 22:13:47                      Cris Barrish
# 3     2023-05-03 01:33:54             Johnny Perez-Gonzalez
# 4     2023-08-06 13:28:37                       Tom Krisher
# ...                   ...                               ...
# 2921  2023-09-14 04:03:24    Matthew Daly, Associated Press
# 2922  2023-11-25 13:42:34  Alexa St. John, Associated Press
# 2923  2023-11-22 20:30:00                      Tyler Durden
# 2924  2023-11-24 08:35:00                      Tyler Durden
# 2925  2023-09-15 12:50:33                               NaN
#
#                                                maintext  \
# 0     For as much as we’ve heard Postmaster General ...
# 1     The EPA says the industry could meet the limit...
# 2     This story is part of the WHYY News Climate De...
# 3     This story is part of the WHYY News Climate De...
# 4     The U.S. government’s most ambitious plan ever...
# ...                                                 ...
# 2921  WASHINGTON – Efforts by the Biden administrati...
# 2922  The negative impact on the climate from passen...
# 2923  Electric vehicles are a fast growing segment i...
# 2924  Authored by Brent Bennett & Andrea Hitt via Re...
# 2925  OAN’s Abril Elfi\n12:50 PM – Friday, September...
#
#                                   preprocessed_maintext  \
# 0     much hear Postmaster General Louis DeJoy talk ...
# 1     EPA say industry could meet limit new vehicle ...
# 2     story part WHYY News Climate Desk bring news s...
# 3     story part WHYY News Climate Desk bring news s...
# 4     U S government ambitious plan ever slash plane...
# ...                                                 ...
# 2921  WASHINGTON effort Biden administration limit p...
# 2922  negative impact climate passenger vehicle cons...
# 2923  electric vehicle fast grow segment U S much ma...
# 2924  author Brent Bennett Andrea Hitt via RealClear...
# 2925  OAN Abril Elfi pm Friday September 2023 United...
#
#             extracted_domain   normalized_domain              domain  \
# 0       www.commondreams.org    commondreams.org    commondreams.org
# 1               www.wmur.com            wmur.com            wmur.com
# 2                   whyy.org            whyy.org            whyy.org
# 3                   whyy.org            whyy.org            whyy.org
# 4             www.nbcdfw.com          nbcdfw.com          nbcdfw.com
# ...                      ...                 ...                 ...
# 2921  www.clickondetroit.com  clickondetroit.com  clickondetroit.com
# 2922  www.clickondetroit.com  clickondetroit.com  clickondetroit.com
# 2923       www.zerohedge.com       zerohedge.com       zerohedge.com
# 2924       www.zerohedge.com       zerohedge.com       zerohedge.com
# 2925            www.oann.com            oann.com            oann.com
#
#       bias_score bias_category  topic_number  \
# 0        -0.6526     Most Left             9
# 1         0.1866       Central             9
# 2        -0.6174     Most Left             9
# 3        -0.6174     Most Left             9
# 4         0.3781    Lean Right             9
# ...          ...           ...           ...
# 2921      0.0795       Central             9
# 2922      0.0795       Central             9
# 2923      0.6771    Most Right             9
# 2924      0.6771    Most Right             9
# 2925      0.8644    Most Right             9
#
#                                          topic_keywords  num_topics  \
# 0     0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# 1     0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# 2     0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# 3     0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# 4     0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# ...                                                 ...         ...
# 2921  0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# 2922  0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# 2923  0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# 2924  0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
# 2925  0.040*"vehicle" + 0.025*"electric" + 0.022*"em...          35
#
#                                       filtered_maintext
# 0     For as much as we’ve heard Postmaster General ...
# 1     The EPA says the industry could meet the limit...
# 2     This story is part of the WHYY News Climate De...
# 3     This story is part of the WHYY News Climate De...
# 4     The U.S. government’s most ambitious plan ever...
# ...                                                 ...
# 2921  WASHINGTON – Efforts by the Biden administrati...
# 2922  The negative impact on the climate from passen...
# 2923  Electric vehicles are a fast growing segment i...
# 2924  Authored by Brent Bennett & Andrea Hitt via Re...
# 2925  OAN’s Abril Elfi 12:50 PM – Friday, September ...
#
# [2926 rows x 15 columns]
